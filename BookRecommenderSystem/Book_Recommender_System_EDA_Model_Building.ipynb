# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Read data

# %%
books = pd.read_csv("data/Books.csv")
users = pd.read_csv("data/Users.csv")
ratings = pd.read_csv("data/Ratings.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %% [markdown]
# ### EDA

# %%
print('='*20, ' COLUMNS ', '='*20)
print('\n', '-'*20, '1. Books ', '-'*20)
print(books.columns)

print('\n', '-'*20, '2. Ratings ', '-'*20)
print(ratings.columns)

print('\n', '-'*20, '3. Users ', '-'*20)
print(users.columns)


print('\n\n')
print('='*20, ' MISSING VALUES ', '='*20)
print('\n', '-'*20, '1. Books ', '-'*20)
print(books.isna().sum() )

print('\n', '-'*20, '2. Ratings ', '-'*20)
print(ratings.isna().sum() )

print('\n', '-'*20, '3. Users ', '-'*20)
print(users.isna().sum() )
# Out:
# ====================  COLUMNS  ====================
#
#  -------------------- 1. Books  --------------------
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
#
#  -------------------- 2. Ratings  --------------------
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')
#
#  -------------------- 3. Users  --------------------
# Index(['User-ID', 'Location', 'Age'], dtype='object')
#
#
#
# ====================  MISSING VALUES  ====================
#
#  -------------------- 1. Books  --------------------
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64
#
#  -------------------- 2. Ratings  --------------------
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64
#
# ...

# %%
# duplicates
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
sub_book = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',]]

# %%
sub_book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company

# %%
sub_book['Book-Author'].value_counts()
# Out:
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# Linda Jackson             1
# Artiste C. Arthur         1
# Emily Pearl Kingsley      1
# Jean Cassels              1
# Christopher  Biffle       1
# Name: Book-Author, Length: 102023, dtype: int64

# %% [markdown]
# ### Popularity Based Recommender

# %%
ratingsbook = ratings.merge(books, on="ISBN")

# %%
ratingsbook.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# ...

# %%
# find our number of votes in each book
count_rating_df = ratingsbook.groupby('Book-Title').count()['Book-Rating'].reset_index()
count_rating_df.rename(columns={'Book-Rating':'num_ratings'}, inplace=True)
count_rating_df.head()
# Out:
#                                           Book-Title  num_ratings
# 0   A Light in the Storm: The Civil War Diary of ...            4
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4   Beyond IBM: Leadership Marketing and Finance ...            1

# %%
# find average rating
avg_rating_df = ratingsbook.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'}, inplace=True)
avg_rating_df.head()
# Out:
#                                           Book-Title  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
popular_book_df = count_rating_df.merge(avg_rating_df, on="Book-Title")
popular_book_df.head()
# Out:
#                                           Book-Title  num_ratings  avg_rating
# 0   A Light in the Storm: The Civil War Diary of ...            4        2.25
# 1                              Always Have Popsicles            1        0.00
# 2               Apple Magic (The Collector's series)            1        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...            1        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...            1        0.00

# %% [markdown]
# ### Popularity Recommender
# We take out top 50 popular books whose `num_ratings` >=250 and we sort with `avg_rating`.

# %%
popular_book_df[popular_book_df['num_ratings'] >= 250]
# Out:
#                                                Book-Title  num_ratings  \
# 764                                                  1984          284
# 818                                   1st to Die: A Novel          509
# 1048                                           2nd Chance          356
# 1760                                   A Bend in the Road          346
# 2281    A Child Called \It\": One Child's Courage to S...          265
# ...                                                   ...          ...
# 233850                           White Oleander : A Novel          387
# 233851       White Oleander : A Novel (Oprah's Book Club)          356
# 234740  Wicked: The Life and Times of the Wicked Witch...          326
# 234951                                        Wild Animus         2502
# 240860                                \O\" Is for Outlaw"          269
#
#         avg_rating
# 764       4.454225
# 818       3.575639
# 1048      3.269663
# 1760      3.364162
# ...

# %%
# finding top 50 books
popular_book_df = popular_book_df[popular_book_df['num_ratings'] >= 250].sort_values('avg_rating', ascending=False).head(50)

# %%
popular_book_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
# merge with book df
# drop duplicates like one book with multiple ISBN
# take out required columns
columns_to_keep = ['Book-Title', 'Book-Author', 'Image-URL-M', 'num_ratings', 'avg_rating']
popular_book_df = popular_book_df.merge(books, on="Book-Title").drop_duplicates('Book-Title')[columns_to_keep]

# %%
popular_book_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# ### Collaborative Filtering Recommendation System

# %% [markdown]
# <pre>
# books  -> book_name
# ratings -> userid
#   \    \
#    \    \-> bookid
#     \
#      \---->rating
#
# </pre>
#
# <pre>
#
#       user1 |  user2  | ..... | user3
# book1  5    |   3     | ......| 10
# book2  1    |   0     | ......| 8
#   .
#   .
#   .
# bookn  9    |   7     | ......| 10
# </pre>
#
# ##### Criteria
#
# To be good recommender system:
# * We only pick those users who give ratings to at least 200 books
# * And We only pick those books who have at least 50 ratings.
#
# Note: this values obtained through experimentation

# %% [markdown]
# ##### First we filter out user that give at least 200 ratings

# %%
cond = ratingsbook.groupby(['User-ID']).count()['Book-Rating'] > 200
most_reader_users = cond[cond].index

# %%
most_reader_users.shape
# Out:
# (811,)

# %%
filtered_ratings = ratingsbook[ratingsbook['User-ID'].isin(most_reader_users)]

# %%
filtered_ratings.shape
# Out:
# (474007, 10)

# %% [markdown]
# #### Analysis shows that 811 users give 474007 ratings

# %% [markdown]
# ##### Find out  books who have at least 50 ratings

# %%
f = filtered_ratings.groupby('Book-Title').count()['Book-Rating'] >=50
famous_books = f[f].index

# %%
famous_books.shape
# Out:
# (706,)

# %% [markdown]
# ##### There are 706 books that have at least 50 ratings

# %%
final_ratings = filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks                1996             Warner Books
# ...

# %%
final_ratings['Image-URL-M'][63]
# Out:
# 'http://images.amazon.com/images/P/0446520802.01.MZZZZZZZ.jpg'

# %% [markdown]
# final_ratings[0]['']

# %% [markdown]
# ##### It shows that 706 books that have at least 50 ratings are rated total of 58586 times

# %%
pt = final_ratings.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0, inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %% [markdown]
# ##### We have total 810 users as columns and 706 as rows top popular books

# %% [markdown]
# * Here, each book contains 810 vectors as 810 users. So, each book represented by 810 dimensional space.
# * We find out eucledian distance for each  vector and from that we know which book is similar to each other.
# * Cosine Similarity gives (706x706) matrix which represents similarity scores of each book to all book including itself. So, always diagonal are 1 i.e. similarity scores to itself is always 1.

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
# fetch index
index = np.where(pt.index=='1984')[0][0]

# %%
# find out similar books with distances from similarity scores
sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:6]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123497),
#  (82, 0.23669374347400993),
#  (634, 0.23299389358170394),
#  (551, 0.2262639743141286)]

# %%
# recommend
def recommend(book_name):
    suggestions = []
    # index fetch 
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:6]
    
    for item in similar_items:
        print(pt.index[item[0]])
        suggestions.append(pt.index[item[0]])
#     return suggestions

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %% [markdown]
# ### Test

# %%
#test
recommend('Message in a Bottle')
# 'Message in a Bottle' is a Nicholas Spark Book
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes

# %%
recommend('The Notebook')
# Out:
# A Walk to Remember
# The Rescue
# One Door Away from Heaven
# Toxin
# The Five People You Meet in Heaven

# %%
recommend('1984')
# Out:
# Animal Farm
# The Handmaid's Tale
# Brave New World
# The Vampire Lestat (Vampire Chronicles, Book II)
# The Hours : A Novel

# %%
recommend('The Hours : A Novel')
# Out:
# The Hitchhiker's Guide to the Galaxy
# A Thousand Acres (Ballantine Reader's Circle)
# The English Patient
# The Bonesetter's Daughter
# The Fourth Hand

# %%
recommend("The Da Vinci Code")
# Out:
# Angels &amp; Demons
# Touching Evil
# Saving Faith
# The Sweet Potato Queens' Book of Love
# Middlesex: A Novel

# %%
recommend('The Hobbit : The Enchanting Prelude to The Lord of the Rings')
# Out:
# The Two Towers (The Lord of the Rings, Part 2)
# The Fellowship of the Ring (The Lord of the Rings, Part 1)
# Where the Red Fern Grows
# One for the Money (A Stephanie Plum Novel)
# The Return of the King (The Lord of the Rings, Part 3)

# %%
recommend('The Fellowship of the Ring (The Lord of the Rings, Part 1)')
# Out:
# The Two Towers (The Lord of the Rings, Part 2)
# The Return of the King (The Lord of the Rings, Part 3)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Chamber of Secrets (Book 2)

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Order of the Phoenix (Book 5)

# %%
# recommend
def recommend2(book_name):
    suggestions = []
    # index fetch 
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:5]
    data = []
    for item in similar_items:
        row = []
        temp_df = books[books['Book-Title'] == pt.index[item[0]] ]
        temp_df = temp_df.drop_duplicates('Book-Title')
        row.append(temp_df['Book-Title'].values[0])
        row.append(temp_df['Book-Author'].values[0])
        row.append(temp_df['Image-URL-M'].values[0])
        
        data.append(row)
    return data

# %%
recommend2('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %% [markdown]
# ### Exporting data and records

# %%
import pickle

# %%
popular_book_df.head(1)
# Out:
#                                           Book-Title    Book-Author  \
# 0  Harry Potter and the Prisoner of Azkaban (Book 3)  J. K. Rowling
#
#                                          Image-URL-M  num_ratings  avg_rating
# 0  http://images.amazon.com/images/P/0439136350.0...          428    5.852804

# %%
pickle.dump(popular_book_df, open('popular_df.pickle', 'wb'))

# %%
pickle.dump(books, open('books.pickle', 'wb'))

# %%
pickle.dump(similarity_scores, open('similarity_scores.pickle', 'wb'))

# %%
pickle.dump(pt, open('pivot_table.pickle', 'wb'))
